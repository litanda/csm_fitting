# %% [markdown]
# # This notebook is to demostrate using the Correlated systematic model to fit to asteroseismic mode frequencies.

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import glob
from scipy.optimize import curve_fit
import re
import math
import os
import matplotlib.pyplot #
from astropy.io import ascii

import warnings
import random
import time
import re
import os, sys
import csv
from mpl_toolkits.mplot3d import Axes3D
import corner

fontsize = 20

params = {'legend.fontsize': fontsize,
          'figure.figsize': (11, 10),
         'axes.labelsize': fontsize,
         'axes.titlesize':fontsize,
         'xtick.labelsize':fontsize,
         'ytick.labelsize':fontsize}
matplotlib.rcParams.update(params)
plt = matplotlib.pyplot

# %% [markdown]
# # Issues in the grid-based approach
# In detailed modelling, grid-based approach is widely used. However, it is expensive to make a grid with very high resolution because of the computational costs. When fitting to observed frequencis, a typical model grid always does not have enough frequency resolution for a proper fitting. Let us first inspect an estibalished model grid computed with MESA and GYRE codes with a grid step of 0.01 for mass, 0.1 dex for [Fe/H], 0.02 for Y, and 0.2 for a_{MLT}.

# %%
datadr = 'sun-as-a-star/models/'
savedr = ''

# %%
nu_0_n_number = [i for i in range(1,41)]
nu_0_n_text = ['nu_0_%s' % s for s in nu_0_n_number]

# %%
starset0 = pd.read_csv(datadr + "01_fit_global.csv", index_col = 0)
# starset0.star_age = starset0.star_age/1.0e9

starset0 = starset0[((starset0.initial_MLT>1.6) & (starset0.initial_MLT<2.6))]

starset0['log_age'] = np.log10(starset0.star_age*1.0e9)
starset0['mean_density'] = starset0.star_mass/starset0.radius**3.0
starset0['dnu'] = 135.1*(starset0.mean_density**0.5)
starset0['numax'] = 3100.0 * 10**(starset0.log_g - 4.44) * (starset0.effective_T/5777.0)**(-0.5)
starset0.index = range(len(starset0))
starset0
# Out:
#                                  csvname    filename  model_number  \
# 0        m1.0Y0.24FeH-0.1MLT2.3ov0.0dif1  profile448           596
# 1        m1.0Y0.24FeH-0.1MLT2.3ov0.0dif1  profile449           597
# 2        m1.0Y0.24FeH-0.1MLT2.3ov0.0dif1  profile450           598
# 3        m1.0Y0.24FeH-0.1MLT2.3ov0.0dif1  profile451           599
# 4        m1.0Y0.24FeH-0.1MLT2.3ov0.0dif1  profile452           600
# ...                                  ...         ...           ...
# 1557239  m1.13Y0.26FeH0.1MLT2.1ov0.0dif1  profile665           813
# 1557240  m1.13Y0.26FeH0.1MLT2.1ov0.0dif1  profile666           814
# 1557241  m1.13Y0.26FeH0.1MLT2.1ov0.0dif1  profile667           815
# 1557242  m1.13Y0.26FeH0.1MLT2.1ov0.0dif1  profile668           816
# 1557243  m1.13Y0.26FeH0.1MLT2.1ov0.0dif1  profile669           817
#
#          evol_stage  initial_mass  initial_feh  initial_Yinit  initial_MLT  \
# 0                 1          1.00         -0.1           0.24          2.3
# 1                 1          1.00         -0.1           0.24          2.3
# 2                 1          1.00         -0.1           0.24          2.3
# 3                 1          1.00         -0.1           0.24          2.3
# 4                 1          1.00         -0.1           0.24          2.3
# ...             ...           ...          ...            ...          ...
# 1557239           1          1.13          0.1           0.26          2.1
# 1557240           1          1.13          0.1           0.26          2.1
# 1557241           1          1.13          0.1           0.26          2.1
# 1557242           1          1.13          0.1           0.26          2.1
# 1557243           1          1.13          0.1           0.26          2.1
#
#          star_mass  star_age  ...      nu_0_39      nu_0_40  lk_effective_T  \
# 0             1.00  0.633480  ...  6557.340377  6710.807359        0.004638
# 1             1.00  0.658779  ...  6550.903344  6704.168313        0.004639
# 2             1.00  0.684067  ...  6544.496074  6697.559842        0.004639
# 3             1.00  0.709343  ...  6538.117782  6690.981132        0.004639
# 4             1.00  0.734608  ...  6531.763169  6684.426756        0.004638
# ...            ...       ...  ...          ...          ...             ...
# 1557239       1.13  3.648408  ...  4325.064981  4428.906353        0.000092
# 1557240       1.13  3.660020  ...  4320.748812  4424.524697        0.000092
# 1557241       1.13  3.671589  ...  4316.455225  4420.165878        0.000093
# 1557242       1.13  3.683116  ...  4312.177970  4415.823451        0.000093
# 1557243       1.13  3.694600  ...  4307.917178  4411.497531        0.000094
#
#          lk_log_g    lk_feh  lk_total   log_age  mean_density         dnu  \
# 0        2.097890  2.218546  0.438607  8.801733      1.439311  162.081230
# 1        2.103246  2.210291  0.438133  8.818740      1.436546  161.925472
# 2        2.108567  2.202065  0.437624  8.835099      1.433797  161.770447
# 3        2.113853  2.193868  0.437080  8.850857      1.431063  161.616140
# 4        2.119108  2.185697  0.436502  8.866056      1.428342  161.462418
# ...           ...       ...       ...       ...           ...         ...
# 1557239  1.985872  3.953566  0.014659  9.562103      0.637743  107.889241
# 1557240  1.980066  3.954909  0.014697  9.563483      0.636482  107.782506
# 1557241  1.974271  3.956220  0.014736  9.564854      0.635228  107.676297
# 1557242  1.968480  3.957499  0.014776  9.566215      0.633980  107.570462
# 1557243  1.962692  3.958746  0.014817  9.567567      0.632737  107.465004
#
#                numax
# 0        3933.156034
# 1        3927.895687
# 2        3922.661205
# 3        3917.452381
# 4        3912.264840
# ...              ...
# 1557239  2332.588557
# 1557240  2329.543157
# 1557241  2326.513878
# 1557242  2323.496944
# 1557243  2320.492392
#
# [1557244 rows x 67 columns]

# %%
plt.scatter(starset0.effective_T, starset0.log_g, s = 10, alpha = 0.3)
plt.text(5777,4.44, r'$\odot$', fontsize = 30)
plt.xlim(6400,5200)
plt.ylim(4.7,4.1)
plt.xlabel(r'$T_{eff}$ (K)')
plt.ylabel(r'$\log g$')
# Out:
# Text(0, 0.5, '$\\log g$')

# %% [markdown]
# We plot models around the sun within the range of Teff = 5777±300K and logg = 4.44±0.3dex on the Teff-logg diagram. This model grid is fine enough to fit the sun's atomosphere. However, if we inspect the model frequencies as below:

# %%
bestset = starset0.copy()
bestset['lk_mean_density'] = np.exp(-(bestset.mean_density - 1.0005)**2.0/2/0.0001)

obsnu_0_n_number = [i for i in range(12,30)]
obsnu_0_n_text = ['nu_0_%s' % s for s in obsnu_0_n_number]

model1 = bestset[(
                  (bestset.initial_mass == 0.99) 
                  & (bestset.initial_Yinit == 0.26)
                  & (bestset.initial_MLT == 2.1)
                  & (bestset.initial_feh == 0.0)
                 )].reset_index()

model2 = bestset[(
                  (bestset.initial_mass == 1.00) 
                  & (bestset.initial_Yinit == 0.26)
                  & (bestset.initial_MLT == 2.1)
                  & (bestset.initial_feh == 0.0)
                 )].reset_index()

model3 = bestset[(
                  (bestset.initial_mass == 1.01) 
                  & (bestset.initial_Yinit == 0.26)
                  & (bestset.initial_MLT == 2.1)
                  & (bestset.initial_feh == 0.0)
                 )].reset_index()

fig, (ax, axx) = plt.subplots(1,2,figsize = (16,10))
obsdnu = 135.1
# frequencies on the ED
ax.scatter(model1.loc[model1.lk_mean_density.argmax(),obsnu_0_n_text] % obsdnu, model1.loc[model1.lk_mean_density.argmax(),obsnu_0_n_text], label = r'Model (0.99M$_{\odot}$)',facecolors='none',edgecolors='r', s = 70)
ax.scatter(model2.loc[model2.lk_mean_density.argmax(),obsnu_0_n_text] % obsdnu, model2.loc[model2.lk_mean_density.argmax(),obsnu_0_n_text], label = r'Model (1.00M$_{\odot}$)', marker = '^',facecolors='none',edgecolors='r', s = 70)
ax.scatter(model3.loc[model3.lk_mean_density.argmax(),obsnu_0_n_text] % obsdnu, model3.loc[model3.lk_mean_density.argmax(),obsnu_0_n_text], label = r'Model (1.01M$_{\odot}$)', marker = 's',facecolors='none',edgecolors='r', s = 70)
ax.set_xlim(40, 120)
ax.set_ylim(1600,4800)
ax.legend(loc = 'lower right')
ax.set_xlabel(r'$\nu$ mod $\Delta\nu$ ($\mu$Hz)')
ax.set_ylabel(r'$\nu$ mod $\Delta\nu$ ($\mu$Hz)')

# plot differences 
axx.scatter(obsnu_0_n_number,
            model1.loc[model1.lk_mean_density.argmax(),obsnu_0_n_text] - model2.loc[model2.lk_mean_density.argmax(),obsnu_0_n_text],
            c = 'b', label = 'Model(M = 0.99) - Model(M = 1.00)'
           )
axx.scatter(obsnu_0_n_number,
            model2.loc[model2.lk_mean_density.argmax(),obsnu_0_n_text] - model3.loc[model3.lk_mean_density.argmax(),obsnu_0_n_text],
            c = 'r', label = 'Model(M = 1.00) - Model(M = 1.01)'
           )
axx.set_xlabel('n')
axx.set_ylabel(r'$\delta\nu$')
axx.legend(fontsize = 15)

# %% [markdown]
# It can be seen that the frequency resolution (at the same mean density but different input mass) is relatively loose. Compared to the typical observed uncertainty (below 0.5microHz), this model uncertainty is large. If we fit model to data without considering any model systematics, we will apparently obtain unreliable estimates.

# %% [markdown]
# # Let us use a fake stars to see demostrate fitting with an under sampled grid.
#
# - The fake star is computed with the same input physics but the input fundemental parameters (mass, metallicity, etc.) are off-grid.
#
# - We use three classical constraints with a typical uncertainty as ±50K for Teff, ±0.1dex for logg, and ±0.1 dex for [Fe/H].
#
# - we assume a constant observed uncertainty which is ± 0.5 microHz

# %%
fakeset = pd.read_csv(datadr + "01_fit_global_fake_sun.csv", index_col = 0)
fakeset['log_age'] = np.log10(fakeset.star_age*1.0e9)
fakeset['mean_density'] = fakeset.star_mass/fakeset.radius**3.0
fakeset['dnu'] = 135.1*(fakeset.mean_density**0.5)
fakeset['numax'] = 3100.0 * 10**(fakeset.log_g - 4.44) * (fakeset.effective_T/5777.0)**(-0.5)

nuse = (
          (fakeset.initial_mass >= 0.99) 
        & (np.abs(fakeset.effective_T - 5777) <=6)
        & (np.abs(fakeset.log_g - 4.44) <=0.01)
        & (np.abs(fakeset.star_feh - 0.0) <=0.05)
       )
fakestar = fakeset[nuse].reset_index()

# observed constraints

obs_teff_e = 50.0
obs_logg_e = 0.1
obs_feh_e = 0.1

obs_teff = fakestar.effective_T.values 
# + np.random.normal(loc=0.0, scale=1.0, size=1)*obs_teff_e
obs_logg = fakestar.log_g.values 
# + np.random.normal(loc=0.0, scale=1.0, size=1)*obs_logg_e
obs_feh = fakestar.star_feh.values 
# + np.random.normal(loc=0.0, scale=1.0, size=1)*obs_feh_e

# The global seismic constraints

obs_dnu = fakestar.delta_nu_fit.values[0]
obs_numax = fakestar.numax.values[0]

# We use radial modes for n = 12 - 30 as observed mode frequencies

obsnu_0_n_number = [i for i in range(12,30)]
obsnu_0_n_text = ['nu_0_%s' % s for s in obsnu_0_n_number]

obs_nu0 = fakestar[obsnu_0_n_text].values
obs_nu0_e = np.full(shape = (len(obsnu_0_n_text)), fill_value = 0.5)

obs_nu0 = obs_nu0[0] 
# + np.random.normal(loc=0.0, scale=1.0, size=len(obs_nu0))*0.1

m,b = np.polyfit(obsnu_0_n_number,obs_nu0, 1) 

# truths of fundemantial inputs

cc = ['star_mass','radius','star_age','initial_Yinit', 'initial_MLT']
truths = fakestar[cc].values
truths = truths[0]


print('True parameters for the fake star')
print('Teff = ', fakestar.effective_T.values)
print('logg = ', fakestar.log_g.values)
print('[Fe/H] = ', fakestar.star_feh.values)
# 
print('M = ', fakestar.star_mass.values)
print('Y = ', fakestar.initial_Yinit.values)
print('MLT = ', fakestar.initial_MLT.values)
print(r'tau = ', fakestar.star_age.values)
print('R = ', fakestar.radius.values)
print(r'rho = ', fakestar.mean_density.values)
#
print('Dnu = ', m)
print('nu_max = ', obs_numax)
print('nu = ', obs_nu0)
# Out:
# True parameters for the fake star
# Teff =  [5771.15247183]
# logg =  [4.43388492]
# [Fe/H] =  [-0.0497064]
# M =  [1.00536]
# Y =  [0.25555]
# MLT =  [1.98171]
# tau =  [3.99452517]
# R =  [1.00730971]
# rho =  [0.98363176]
# Dnu =  134.40046818441462
# nu_max =  3058.2044726049726
# nu =  [1801.06420486 1935.1563683  2069.22650747 2203.37215522 2336.27117792
#  2468.50004092 2601.51793609 2735.1567911  2869.55037137 3003.92574358
#  3138.37825574 3273.25875276 3408.3199944  3543.98771096 3679.81222332
#  3815.84730696 3952.06727292 4088.27283061]

# %% [markdown]
# # Here we write a simple script to do MLE fitting for mode frequencies. Note that there is not surface term for the fake star

# %%
class smart_fit:
    '''
    '''
    
    def __init__(self):
        return None
    
    def mle(self, model, obs, obs_e):
        return -0.5*(model - obs)**2.0/obs_e**2.0
    
    def fit_modes(self, obs_nu, obs_nu_e, modeldf, nucolumns, lkcolumn):
        
        if lkcolumn in modeldf.columns:
            modeldf.loc[:,lkcolumn] = -1.0e99
        else:    
            modeldf.insert(loc = len(modeldf.columns), column = lkcolumn, value = -1.0e99,allow_duplicates=False) 
        
        for index, row in modeldf.iterrows():
            loglk = 0.0            
            model = row[nucolumns]
            loglk = self.mle(model, obs_nu, obs_nu_e)
            modeldf.loc[index, lkcolumn] = np.sum(loglk)
        return modeldf
sfit = sfit = smart_fit()

# %%
# Fit to classical constraints and obtain 'lk_spectro'
starset0['lk_effective_T'] = sfit.mle(starset0.effective_T, obs_teff, obs_teff_e)
starset0['lk_log_g'] = sfit.mle(starset0.log_g, obs_logg, obs_logg_e)
starset0['lk_feh'] = sfit.mle(starset0.star_feh, obs_feh, obs_feh_e)
starset0['lk_spectro'] = starset0['lk_effective_T'] + starset0['lk_log_g'] + starset0['lk_feh']

# Only select models that fits to classical constraints  
starset = starset0[starset0.lk_spectro >= -3.0]
# and we remove models that deviate too much from the obs
nuse = ( (np.median(obs_nu0 - starset[obsnu_0_n_text], axis = 1) < +0.02*obs_numax) &
         (np.median(obs_nu0 - starset[obsnu_0_n_text], axis = 1) > -0.02*obs_numax)
       )
starset = starset[nuse]
starset.index = range(len(starset))
starset
# Out:
#                                csvname    filename  model_number  evol_stage  \
# 0      m1.0Y0.24FeH-0.1MLT2.3ov0.0dif1  profile610           758           1
# 1      m1.0Y0.24FeH-0.1MLT2.3ov0.0dif1  profile611           759           1
# 2      m1.0Y0.24FeH-0.1MLT2.3ov0.0dif1  profile612           760           1
# 3      m1.0Y0.24FeH-0.1MLT2.3ov0.0dif1  profile613           761           1
# 4      m1.0Y0.24FeH-0.1MLT2.3ov0.0dif1  profile614           762           1
# ...                                ...         ...           ...         ...
# 24675  m0.91Y0.32FeH0.2MLT2.3ov0.0dif1  profile690           838           1
# 24676  m0.91Y0.32FeH0.2MLT2.3ov0.0dif1  profile691           839           1
# 24677  m0.91Y0.32FeH0.2MLT2.3ov0.0dif1  profile692           840           1
# 24678  m0.91Y0.32FeH0.2MLT2.3ov0.0dif1  profile693           841           1
# 24679  m0.91Y0.32FeH0.2MLT2.3ov0.0dif1  profile694           842           1
#
#        initial_mass  initial_feh  initial_Yinit  initial_MLT  star_mass  \
# 0              1.00         -0.1           0.24          2.3       1.00
# 1              1.00         -0.1           0.24          2.3       1.00
# 2              1.00         -0.1           0.24          2.3       1.00
# 3              1.00         -0.1           0.24          2.3       1.00
# 4              1.00         -0.1           0.24          2.3       1.00
# ...             ...          ...            ...          ...        ...
# 24675          0.91          0.2           0.32          2.3       0.91
# 24676          0.91          0.2           0.32          2.3       0.91
# 24677          0.91          0.2           0.32          2.3       0.91
# 24678          0.91          0.2           0.32          2.3       0.91
# 24679          0.91          0.2           0.32          2.3       0.91
#
#        star_age  ...      nu_0_40  lk_effective_T  lk_log_g    lk_feh  \
# 0      4.541005  ...  5632.860050       -1.867338 -0.006087 -0.624358
# 1      4.563743  ...  5625.858076       -1.884263 -0.005333 -0.627804
# 2      4.586462  ...  5618.853944       -1.901180 -0.004628 -0.631249
# 3      4.609161  ...  5611.846410       -1.918074 -0.003971 -0.634693
# 4      4.631842  ...  5604.835066       -1.934942 -0.003363 -0.638135
# ...         ...  ...          ...             ...       ...       ...
# 24675  7.286971  ...  5434.165317       -0.011472 -0.031169 -1.468182
# 24676  7.310402  ...  5426.184998       -0.011015 -0.033314 -1.464284
# 24677  7.333746  ...  5418.228059       -0.010592 -0.035528 -1.460409
# 24678  7.357000  ...  5410.298303       -0.010206 -0.037810 -1.456558
# 24679  7.380168  ...  5402.386701       -0.009847 -0.040160 -1.452730
#
#        lk_total   log_age  mean_density         dnu        numax  lk_spectro
# 0      0.155523  9.657152      1.024577  136.750067  3110.963762   -2.497783
# 1      0.153943  9.659321      1.022081  136.583421  3105.794421   -2.517400
# 2      0.152377  9.661478      1.019587  136.416668  3100.624807   -2.537057
# 3      0.150825  9.663622      1.017094  136.249775  3095.454111   -2.556738
# 4      0.149288  9.665754      1.014601  136.082736  3090.282081   -2.576440
# ...         ...       ...           ...         ...          ...         ...
# 24675  0.461361  9.862547      0.948465  131.572771  2889.243475   -1.510824
# 24676  0.462219  9.863941      0.945701  131.380908  2883.589131   -1.508613
# 24677  0.463048  9.865326      0.942948  131.189576  2877.955329   -1.506529
# 24678  0.463847  9.866701      0.940209  130.998839  2872.344373   -1.504574
# 24679  0.464618  9.868066      0.937479  130.808518  2866.750088   -1.502738
#
# [24680 rows x 68 columns]

# %%
# Fit to mode frequencies and obtain 'lk_seismo_0' (0 for no model systematics)
starset = sfit.fit_modes(obs_nu0, obs_nu0_e, starset, obsnu_0_n_text, 'lk_seismo_0')

# %% [markdown]
# # We make a coner plot for four fundemental parameters.
# - As it can be seen that, a few models stands out and probability distribution is not continuos.
# - This is because the grid is significantly undersampled.

# %% [markdown]
# # Now we consider the model systematics as a white noise
# - Acoording to the plot which illustrates the frequency change between gird points at given mean density, the model uncertianty is at the level of ~1microHz on average and it is also scaled by the frequency.
#
# - As a rough approximation, we adopt a white noise following a linear function of mode frequency, described as sigma_sys = nu/nu_max.

# %%
# Now the mode frequency uncertainties become
nu0_e_sys = 1.5*obs_nu0/obs_numax
print('nu_e = ', np.sqrt(obs_nu0_e**2 + nu0_e_sys**2.0))
# Out:
# nu_e =  [1.01507789 1.07280493 1.13140054 1.19077812 1.25023778 1.30993837
#  1.37046805 1.43169734 1.49364211 1.55590496 1.61849258 1.68153743
#  1.74489767 1.80875056 1.87286486 1.93724804 2.00187228 2.06662892]

# %%
# We fit models to data again with these mode frequencies and use 'lk_seismo_wn' to represent the likelihood
starset = sfit.fit_modes(obs_nu0, np.sqrt(obs_nu0_e**2 + nu0_e_sys**2.0), starset, obsnu_0_n_text, 'lk_seismo_wn')

# %%
fontsize = 15

params = {'legend.fontsize': fontsize,
          'figure.figsize': (11, 10),
         'axes.labelsize': fontsize,
         'axes.titlesize':fontsize,
         'xtick.labelsize':fontsize,
         'ytick.labelsize':fontsize}
matplotlib.rcParams.update(params)
plt = matplotlib.pyplot

figure = corner.corner(starset[cc], 
                       weights = np.exp(starset.lk_spectro + starset.lk_seismo_wn),
                       bins = 20,
                       smooth=0.5,
                       truths = truths,
                       labels=[r"M (M$_{\odot}$)","R (R$_{\odot}$)", r"$\tau$ (Gyr)", r"$Y$", r"$\alpha_{\rm MLT}$"],
                       quantiles=[0.16, 0.5, 0.84],
                       range = [[0.8,1.15], [0.9,1.1] ,[0,11], [0.23,0.33], [1.6,2.6]],
                       show_titles=True, title_kwargs={"fontsize": 15})
plt.text(-1.3,19, 'Fitting with white systematic noise',fontsize = 25)

figure.savefig('fig_coner_wn.pdf')
plt.show()

# %% [markdown]
# # We make a coner plot for four fundemental parameters again.
# - Now, determinations looks more promising now, and it means the model systematics is neccesary when fitting with a model grid.

# %%
fontsize = 15

params = {'legend.fontsize': fontsize,
          'figure.figsize': (11, 10),
         'axes.labelsize': fontsize,
         'axes.titlesize':fontsize,
         'xtick.labelsize':fontsize,
         'ytick.labelsize':fontsize}
matplotlib.rcParams.update(params)
plt = matplotlib.pyplot

figure = corner.corner(starset[cc], 
                       weights = np.exp(starset.lk_spectro + starset.lk_seismo_wn),
                       bins = 20,
                       smooth=0.5,
                       truths = truths,
                       labels=[r"M (M$_{\odot}$)","R (R$_{\odot}$)", r"$\tau$ (Gyr)", r"$Y$", r"$\alpha_{\rm MLT}$"],
                       quantiles=[0.16, 0.5, 0.84],
                       range = [[0.8,1.15], [0.9,1.1] ,[0,11], [0.23,0.33], [1.6,2.6]],
                       show_titles=True, title_kwargs={"fontsize": 15})
plt.text(-1.3,19, 'Fitting with white systematic noise',fontsize = 25)

figure.savefig('fig_coner_wn.pdf')
plt.show()

# %% [markdown]
# # Is white noise good for describing the model systematics, appearently not.
# - The model systematic model represents models which are not computed between the grid step.
# - Even though we can not compute infinite models, it is known that oscllation mode frequencies of a certain model well correlate to each others according to the theory, while what the white noise predicts are mode frequencies with random bumping.
#
# # We show a couple frequency sets sampled with the white noise below. As an comparison, we also demostrate those sampled with a correlated noise model.
# - The correlated noise model is described as the square exponential kernel (covariance function) with a lengthscale equals to 3 times the large separation. The SE kernel can be integrated against most functions that we need to. Every function in its prior has infinitely many derivatives. The SE kernel only generates SMOOTH functions, saying that, the mode frequency can only change in a correlated way. The strenght of the correlation is determined by a free parameter called lengthscale, which describes the length of the 'wiggles' of the kernel.

# %%
fig, (ax1,ax2) = plt.subplots(1,2)
ax1.scatter(obs_nu0 % obs_dnu*0.95, obs_nu0, c = 'k')
ax1.set_xlim(25,0.5*obs_dnu)

nu = starset.loc[starset.lk_seismo_wn.argmax(), obsnu_0_n_text]

sigma = np.sqrt(obs_nu0_e**2 + nu0_e_sys**2.0)  
n = np.array(obsnu_0_n_number)
length_sys = 3.0*obs_dnu


for i in range(5):
    sys = np.random.randn(len(nu)) * sigma
    nu_ = nu
    mean = -5*(nu/3090.0)**3.0*0
    nu_ = nu_ + sys + mean
    ax1.plot((nu_ % obs_dnu*0.95), nu_, '-o',alpha = 0.3, c = 'r')
ax1.set_title('White noise Model')

ax2.scatter(obs_nu0 % obs_dnu*0.95, obs_nu0, c = 'k')
def SEKernel(x, y, sigma, length):
        return sigma**2 * np.exp(-0.5 * 
                        np.subtract.outer(x, y)**2 / length**2)
for i in range(5):
    Sigma = SEKernel(obs_nu0, obs_nu0, sigma, length_sys)
    sys = -np.random.multivariate_normal((n*0.00)**3, Sigma, size=1)[0]
    mean = -5*(nu/3090.0)**3.0*0
    nu_ = nu + sys  + mean
    ax2.plot(nu_ % obs_dnu*0.95, nu_, '-o',alpha = 0.3, c = 'b')


ax2.set_xlim(25,0.5*obs_dnu)
ax2.set_yticks([])
ax2.set_title('Correlated Noise Model')

ax1.set_xlabel(r'                                              $\nu$ mod $\Delta\nu$ ($\mu$Hz)')
ax1.set_ylabel(r'$\nu$ ($\mu$Hz)')

plt.subplots_adjust(wspace=0, hspace=None)
fig.savefig('fig_wm_cnm.pdf')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:26: RuntimeWarning: covariance is not positive-semidefinite.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:26: RuntimeWarning: covariance is not positive-semidefinite.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:26: RuntimeWarning: covariance is not positive-semidefinite.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:26: RuntimeWarning: covariance is not positive-semidefinite.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:26: RuntimeWarning: covariance is not positive-semidefinite.

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3,1, figsize = (8,10))

nu = starset.loc[starset.lk_seismo_wn.argmax(), obsnu_0_n_text]


def SEKernel(x, y, sigma, length):
        return sigma**2 * np.exp(-0.5 * 
                        np.subtract.outer(x, y)**2 / length**2)
for i in range(10):
    Sigma = SEKernel(obs_nu0, obs_nu0, 1.5*(obs_nu0/obs_numax), 30.0*obs_dnu)
    sys = -np.random.multivariate_normal((n*0.00)**3, Sigma, size=1)[0] 
    ax1.plot(nu,  sys, '-o',alpha = 0.3, c = 'b')
    ax1.set_ylim(-3.5,3.5)
    
    Sigma = SEKernel(obs_nu0, obs_nu0, 0.1*(obs_numax/obs_nu0)**2.0, 2*obs_dnu)
    sys2 = -np.random.multivariate_normal((n*0.00)**3, Sigma, size=1)[0]
    ax2.plot(nu,  sys2, '-o',alpha = 0.3, c = 'r')
    ax2.set_ylim(-0.9,0.9)
    
    ax3.plot(nu,  sys+sys2, '-o',alpha = 0.3, c = 'k')
    ax3.set_ylim(-3.5,3.5)

ax1.set_title('Frequency changes sampled with the uncertainty kernel')
ax1.text(1800,2.0,'Primary Kernel',fontsize = 15)
ax2.text(1800,0.6,'Secondary Kernel',fontsize = 15)
ax3.text(1800,2.0,'Primary Kernel + Secondary Kernel',fontsize = 15)
ax2.set_ylabel(r'$\delta\nu$($\mu$Hz)')
ax3.set_xlabel(r'$\nu$ ($\mu$Hz)')

plt.subplots_adjust(left = 0.1, right = 0.95, bottom = 0.1, top = 0.95, wspace=0, hspace = 0)
fig.savefig('fig_generated_noise.pdf')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: RuntimeWarning: covariance is not positive-semidefinite.
#   # This is added back by InteractiveShellApp.init_path()
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: RuntimeWarning: covariance is not positive-semidefinite.
#   app.launch_new_instance()
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: RuntimeWarning: covariance is not positive-semidefinite.
#   # This is added back by InteractiveShellApp.init_path()
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: RuntimeWarning: covariance is not positive-semidefinite.
#   app.launch_new_instance()
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: RuntimeWarning: covariance is not positive-semidefinite.
#   # This is added back by InteractiveShellApp.init_path()
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: RuntimeWarning: covariance is not positive-semidefinite.
#   app.launch_new_instance()
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: RuntimeWarning: covariance is not positive-semidefinite.
#   # This is added back by InteractiveShellApp.init_path()
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: RuntimeWarning: covariance is not positive-semidefinite.
#   app.launch_new_instance()
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: RuntimeWarning: covariance is not positive-semidefinite.
#   # This is added back by InteractiveShellApp.init_path()
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: RuntimeWarning: covariance is not positive-semidefinite.
#   app.launch_new_instance()
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: RuntimeWarning: covariance is not positive-semidefinite.
#   # This is added back by InteractiveShellApp.init_path()
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: RuntimeWarning: covariance is not positive-semidefinite.
#   app.launch_new_instance()
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: RuntimeWarning: covariance is not positive-semidefinite.
#   # This is added back by InteractiveShellApp.init_path()
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: RuntimeWarning: covariance is not positive-semidefinite.
#   app.launch_new_instance()
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: RuntimeWarning: covariance is not positive-semidefinite.
#   # This is added back by InteractiveShellApp.init_path()
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: RuntimeWarning: covariance is not positive-semidefinite.
#   app.launch_new_instance()
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: RuntimeWarning: covariance is not positive-semidefinite.
#   # This is added back by InteractiveShellApp.init_path()
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: RuntimeWarning: covariance is not positive-semidefinite.
#   app.launch_new_instance()
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: RuntimeWarning: covariance is not positive-semidefinite.
#   # This is added back by InteractiveShellApp.init_path()
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: RuntimeWarning: covariance is not positive-semidefinite.
#   app.launch_new_instance()

# %% [markdown]
# The above figure clearly shows that the white noise model predicts mode frequency sets that can not exist in theoretical models. What the correlated noise model samples, although they are not exactly the same as real models, but more like what models should have.

# %% [markdown]
# # Now update our fitting script by involving the correlated noise model based on the square exponiential kernel.
#
# - There are two free parameters in the SE kernel function (see details on https://www.cs.toronto.edu/~duvenaud/cookbook/)
# - The lengthscale l determines the length of the 'wiggles' in your function. In general, you won't be able to extrapolate more than units away from your data.
# - The output variance sigma^2 determines the average distance of your function away from its mean. Every kernel has this parameter out in front; it's just a scale factor.

# %% [markdown]
# # Determining the lengthscale
#
# - In our case, the lengthscale represent the correlation between model frequencies. The SE kernel with a small lengthscale (e.g., l = Dnu0) gives a noise model similar to the white noise. A very large lengthscale gives a very smooth funcion which means that modes only change in a tigthly correlated way. We determine the lengthscale by inspecting the frequency differences between consecutive grid points at different dimissions.
#
# - The patterm of frequency differencies between grid points is smooth but contents small 'wiggles' whose amplitude is approximately equals to or less than 0.5 microHz.
#
# - A proper noise model for this is a combination of a kernel with large lengthscale and variance (describing the general trend) plus another kernel with small lengthscale and variacne (describing the wiggles).
#
# - Here we determine the lengthscale for the two kernels. The 1st kernel should have a significantly large lengthscale because the frequency changes between grid points generally follow a linear function. We use a lengthscale = 100Dnu for the first kernel. The lengthscale of the 2nd kernel should match the length of 'wiggles'. howerver, the value to use need to be tested.
#
# - Here we test which lengthscales give the best fit to the data.

# %% [markdown]
# # Determining the sigma
#
# - The output variance is the frequency resolution. We hence use what we obtianed above
#
# nu0_e_sys = obs_nu0/obs_numax
#
# as the sigma of SE kernel.

# %% [markdown]
# # We update our fitting script by involving a correlated noise model

# %%
class smart_fit:
    '''
    
    '''
    
    def __init__(self):
        return None
    
    def mle(self, model, obs, obs_e):
        return -0.5*(model - obs)**2.0/obs_e**2.0
    
    def fit_modes(self, obs_nu, obs_nu_e, modeldf, nucolumns, lkcolumn):
        
        if lkcolumn in modeldf.columns:
            modeldf.loc[:,lkcolumn] = -1.0e99
        else:    
            modeldf.insert(loc = len(modeldf.columns), column = lkcolumn, value = -1.0e99,allow_duplicates=False) 
        
        for index, row in modeldf.iterrows():
            loglk = 0.0            
            model = row[nucolumns]
            loglk = self.mle(model, obs_nu, obs_nu_e)
            modeldf.loc[index, lkcolumn] = np.sum(loglk)
        return modeldf
    
#   fit with covirance function
    
    def fit_modes_cov(self, obs_nu = None, obs_nu_e = None, n_order = None,obs_dnu = None,
                       mean_sys = None,
                       sigma_e = None, length_e = None, 
                       sigma_u1 = None, sigma_u1_mlt = None, length_u1 = None,
                       sigma_u2 = None, length_u2 = None, 
                       modeldf = None, nucolumns = None, lkcolumn = None):
        
        if lkcolumn in modeldf.columns:
            modeldf.loc[:,lkcolumn] = -1.0e99
        else:    
            modeldf.insert(loc = len(modeldf.columns), column = lkcolumn, value = -1.0e99,allow_duplicates=False) 
        
        def SEKernel(x, y, sigma, length):
            return sigma**2 * np.exp(-0.5 * np.subtract.outer(x, y)**2 / length**2)
        

        def cov_loglk(model, obs, obs_e, n_order):
            
#           We have four kernels to present the noises in 
#            i) model errors(the surface term), 
#           ii) frequency changes between grid for mass, matellicity, and helium faction 
#          iii) frequency changes between grid for the mixing-length parameter 
#           iv) changes in the glitch signiture between grid.

            Sigma = SEKernel(obs, obs, sigma_e, length_e) \
                  + SEKernel(obs, obs, sigma_u1, length_u1) \
                  + SEKernel(obs, obs, sigma_u1_mlt, length_u1) \
                  + SEKernel(obs, obs, sigma_u2, length_u2)
            
            mean_function = mean_sys
            freq_dif = model + mean_function - obs
            loglk = -0.5 * freq_dif.dot( np.linalg.inv(Sigma + np.identity(len(n_order))*obs_e**2.0)).dot(freq_dif.T) 
            return loglk

        '''
        '''
        for index, row in modeldf.iterrows():
                
            model_nu = row[nucolumns]
     
            modeldf.loc[index, lkcolumn] = cov_loglk(model_nu, obs_nu, obs_nu_e, n_order)
        return modeldf
    
sfit = smart_fit()

# %%
# Here the mean function is zero because there is no model errors in a fake star
mean_sys = obs_nu0*0.0

sigma_e = 0.0
length_e = 5.0*obs_dnu

sigma_u1 = 1.5*obs_nu0/obs_numax
sigma_u1_mlt = 0.0*(obs_nu0/obs_numax)
length_u1 = 20.0*obs_dnu

sigma_u2 = 0.1*(obs_numax/obs_nu0)**2.0
length_u2 = 2.0*obs_dnu



starset = sfit.fit_modes_cov(obs_nu = obs_nu0, obs_nu_e = obs_nu0_e,
                             n_order = np.array(obsnu_0_n_number),obs_dnu = obs_dnu, 
                             mean_sys = mean_sys, 
                             sigma_e = sigma_e, length_e = length_e, 
                             sigma_u1 = sigma_u1, sigma_u1_mlt = sigma_u1_mlt, length_u1 = length_u1,
                             sigma_u2 = sigma_u2, length_u2 = length_u2,
                             modeldf = starset, nucolumns = obsnu_0_n_text, lkcolumn = 'lk_seismo_scn')

# %%
fontsize = 15

params = {'legend.fontsize': fontsize,
          'figure.figsize': (11, 10),
         'axes.labelsize': fontsize,
         'axes.titlesize':fontsize,
         'xtick.labelsize':fontsize,
         'ytick.labelsize':fontsize}
matplotlib.rcParams.update(params)
plt = matplotlib.pyplot

cc = ['star_mass','radius','star_age','initial_Yinit', 'initial_MLT']

figure = corner.corner(starset[cc], 
                       weights = np.exp(starset.lk_spectro + starset.lk_seismo_scn),
                       bins = 20,
                        smooth=0.5,
                       truths = truths,
                       labels=[r"M (M$_{\odot}$)","R (R$_{\odot}$)", r"$\tau$ (Gyr)", r"$Y$", r"$\alpha_{\rm MLT}$"],
                       quantiles=[0.16, 0.5, 0.84],
                       range = [[0.8,1.15], [0.9,1.1] ,[0,11], [0.23,0.33], [1.6,2.6]],
                       show_titles=True, title_kwargs={"fontsize": 15})

plt.text(-1.3,60, 'Fitting with correlated systematic noise',fontsize = 25)

figure.savefig('fig_coner_scn.pdf')
plt.show()

# %%
# plot small

# %%
[truths[0], truths[2]]
# Out:
# [1.00536, 3.99452516652462]

# %%
fontsize = 15

params = {'legend.fontsize': fontsize,
          'figure.figsize': (11, 10),
         'axes.labelsize': fontsize,
         'axes.titlesize':fontsize,
         'xtick.labelsize':fontsize,
         'ytick.labelsize':fontsize}
matplotlib.rcParams.update(params)
plt = matplotlib.pyplot

figure = corner.corner(starset[['star_mass','star_age']], 
                       weights = np.exp(starset.lk_spectro + starset.lk_seismo_wn),
                       bins = 20,
                       smooth=0.5,
                       truths = [truths[0], truths[2]],
                       labels=[r"M (M$_{\odot}$)", r"$\tau$ (Gyr)"],
                       quantiles=[0.16, 0.5, 0.84],
                       range = [[0.8,1.15], [0,11]],
                       show_titles=True, title_kwargs={"fontsize": 15})
plt.text(-18.,3, 'Fitting with white systematic noise',fontsize = 25)
plt.show()


fontsize = 15

params = {'legend.fontsize': fontsize,
          'figure.figsize': (11, 10),
         'axes.labelsize': fontsize,
         'axes.titlesize':fontsize,
         'xtick.labelsize':fontsize,
         'ytick.labelsize':fontsize}
matplotlib.rcParams.update(params)
plt = matplotlib.pyplot

figure = corner.corner(starset[['star_mass','star_age']], 
                       weights = np.exp(starset.lk_spectro + starset.lk_seismo_scn),
                       bins = 20,
                       smooth=0.5,
                       truths = [truths[0], truths[2]],
                       labels=[r"M (M$_{\odot}$)", r"$\tau$ (Gyr)"],
                       quantiles=[0.16, 0.5, 0.84],
                       range = [[0.8,1.15], [0,11]],
                       show_titles=True, title_kwargs={"fontsize": 15})
plt.text(-18,12, 'Fitting with correlated systematic noise',fontsize = 25)
plt.show()

# %%
# # Here the mean function is zero because there is no model errors in a fake star
# mean_sys = obs_nu0*0.0

# sigma_e = 0.0
# length_e = 5.0*obs_dnu

# sigma_u1 = (obs_nu0/obs_numax)*2.0
# sigma_u1_mlt = (obs_numax/obs_nu0)
# length_u1 = 20.0*obs_dnu

# sigma_u2 = 0.2
# length_u2 = 2.0*obs_dnu



# starset = sfit.fit_modes_cov(obs_nu = obs_nu0, obs_nu_e = obs_nu0_e,
#                              n_order = np.array(obsnu_0_n_number),obs_dnu = obs_dnu, 
#                              mean_sys = mean_sys, 
#                              sigma_e = sigma_e, length_e = length_e, 
#                              sigma_u1 = sigma_u1, sigma_u1_mlt = sigma_u1_mlt, 
#                              length_u1 = length_u1,
#                              sigma_u2 = sigma_u2, length_u2 = length_u2,
#                              modeldf = starset, nucolumns = obsnu_0_n_text, lkcolumn = 'lk_seismo_cn')

# %%
# fontsize = 15

# params = {'legend.fontsize': fontsize,
#           'figure.figsize': (11, 10),
#          'axes.labelsize': fontsize,
#          'axes.titlesize':fontsize,
#          'xtick.labelsize':fontsize,
#          'ytick.labelsize':fontsize}
# matplotlib.rcParams.update(params)
# plt = matplotlib.pyplot

# cc = ['star_mass','radius','star_age','initial_Yinit', 'initial_MLT']

# figure = corner.corner(starset[cc], 
#                        weights = np.exp(starset.lk_spectro + starset.lk_seismo_cn),
#                        bins = 20,
#                         smooth=0.5,
#                        truths = truths,
#                        labels=[r"M (M$_{\odot}$)","R (R$_{\odot}$)", r"$\tau$ (Gyr)", r"$Y$", r"$\alpha_{\rm MLT}$"],
#                        quantiles=[0.16, 0.5, 0.84],
#                        range = [[0.8,1.15], [0.9,1.1] ,[0,11], [0.23,0.33], [1.6,2.6]],
#                        show_titles=True, title_kwargs={"fontsize": 15})

# plt.text(-1.3,100, 'Fitting with a comprehensive CNM',fontsize = 25)

# figure.savefig('fig_coner_cn.pdf')
# plt.show()

# %% [markdown]
# # Fits with correlated systematic noise apperantly better recovers the truths of the fake star. Now we make the fake star more like a real star by adding the surface term to its mode frequencies. We also consider the possibility that a few mode frequencies are misreported.
#
# - we add the surface term to the fake star's mode frequencies using kjeldsen&bedding(2008) formula.
# - We shift one of the radial mode frequencies by 2.5microHz (5 sigma) to make it as a misreported frequency.

# %%
# New 'observed' mode frequencies
# we add a surface term using the formula given by kjeldsen&bedding(2008)
a = -4.73
b = 4.90
obs_nu0n = obs_nu0 + a*(obs_nu0/3100)**b + np.random.normal(loc=0.0, scale=1.0, size=len(obs_nu0))*0.5
obs_nu0n[15] = obs_nu0n[15]

print(np.polyfit(obsnu_0_n_number,obs_nu0n, 1))

fig, ax = plt.subplots()
ax.scatter(obs_nu0 % (obs_dnu), obs_nu0, c = 'k', label = 'fake star')
ax.scatter(obs_nu0n % (obs_dnu), obs_nu0n, c = 'b', label = 'realistic fake star')
ax.errorbar(obs_nu0n % (obs_dnu), obs_nu0n, xerr = 0.5, c = 'b', ls = 'None')
ax.set_xlim(25,0.5*obs_dnu)
ax.set_ylim(1400,4200)
ax.legend(loc = 'lower left')
ax.set_xlabel(r'$\nu$ mod $\Delta\nu$ ($\mu$Hz)')
ax.set_ylabel(r'$\nu$ ($\mu$Hz)')
ax.set_title("Mode frequenices of the fake star")
fig.savefig('fig_fake_data.pdf')
# Out:
# [133.43433684 199.15029541]

# %% [markdown]
# # To fit mode to the data with the kernel, we will need a mean function.
#
# - The mean function represent the model systematic errors, which is identified as the frequency offsets between observation and the best-fitting model. However, the best-fitting model is unknow before doting the fits. For this reason, we use two priors to determine the mean funciton. The detials of the method can be seen in the paper.
#
# # To consider the misreported mode, we need to apply the multivariate t-distribution instead of the multivariate normal distribution.
#
# - the t-distribution is basicly a normal distribution with long tails. The tails represent the chance to have an outlier in a population.

# %%
# Here we update our code to involve the mean function and a likeliood function based on the t-distribution

class smart_fit:
    '''
    
    '''
    
    def __init__(self):
        return None
    
    def mle(self, model, obs, obs_e):
        return -0.5*(model - obs)**2.0/obs_e**2.0
    
    def fit_modes(self, obs_nu, obs_nu_e, modeldf, nucolumns, lkcolumn):
        
        if lkcolumn in modeldf.columns:
            modeldf.loc[:,lkcolumn] = -1.0e99
        else:    
            modeldf.insert(loc = len(modeldf.columns), column = lkcolumn, value = -1.0e99,allow_duplicates=False) 
        
        for index, row in modeldf.iterrows():
            loglk = 0.0            
            model = row[nucolumns]
            loglk = self.mle(model, obs_nu, obs_nu_e)
            modeldf.loc[index, lkcolumn] = np.sum(loglk)
        return modeldf
    
#   fit with covirance function

#   fit with covirance function
    
    def fit_modes_cov(self, obs_nu = None, obs_nu_e = None, n_order = None,obs_dnu = None,
                       mean_sys = None,
                       sigma_e = None, length_e = None, 
                       sigma_u1 = None, sigma_u1_mlt = None, length_u1 = None,
                       sigma_u2 = None, length_u2 = None, 
                       modeldf = None, nucolumns = None, lkcolumn = None, dis ='normal'):
        
        if lkcolumn in modeldf.columns:
            modeldf.loc[:,lkcolumn] = -1.0e99
        else:    
            modeldf.insert(loc = len(modeldf.columns), column = lkcolumn, value = -1.0e99,allow_duplicates=False) 
        
        def SEKernel(x, y, sigma, length):
            return sigma**2 * np.exp(-0.5 * np.subtract.outer(x, y)**2 / length**2)

        def cov_loglk(model, obs, obs_e, n_order):
            
#           We have four kernels to present the noises in 
#            i) model errors(the surface term), 
#           ii) frequency changes between grid for mass, matellicity, and helium faction 
#          iii) frequency changes between grid for the mixing-length parameter 
#           iv) changes in the glitch signiture between grid.

            Sigma = SEKernel(obs, obs, sigma_e, length_e) \
                  + SEKernel(obs, obs, sigma_u1, length_u1) \
                  + SEKernel(obs, obs, sigma_u1_mlt, length_u1) \
                  + SEKernel(obs, obs, sigma_u2, length_u2)
            
            mean_function = mean_sys
            freq_dif = model + mean_function - obs
            
            if dis == 'normal': 
                loglk = -0.5 * freq_dif.dot( np.linalg.inv(Sigma + np.identity(len(n_order))*obs_e**2.0)).dot(freq_dif.T) 
            elif dis == 't':
                df = 2
                p = len(n_order)
                loglk = np.log((1.0 + 1/df*freq_dif.dot( np.linalg.inv(Sigma + np.identity(len(n_order))*obs_e**2.0)).dot(freq_dif.T))**(-(df+p)/2))
        
            else: 
                print("Distribution is either 'normal' or 't'!")
                stop
            return loglk

        '''
        '''
        for index, row in modeldf.iterrows():
                
            model_nu = row[nucolumns]
     
            modeldf.loc[index, lkcolumn] = cov_loglk(model_nu, obs_nu, obs_nu_e, n_order)
        return modeldf
    
    
    
    def flattop_gaussian(self, x, mu, sigma):
        return -( (x-mu)**2/2/sigma**2 )**10.0
    
    def gaussian(self, x, mu, sigma):
        return -( (x-mu)**2/2/sigma**2 )
    
#   Determine the mean function: an intitail estimate of the model errors
    def mean_function(self, obs_nu = None, obs_numax = None,
                      model_df = None, nucolumns = None, frac = 0.3,
                      mu_lownu = 0.0, sigma_lownu = 0.001,
                       mu_numax = None, sigma_numax = None,
                       plot = None, ax = None, cmap = None, norm = None):
        
        newcolumn = 'lk_mean'
        df = model_df.copy()
        
        if frac < 1.0:
            df = df.sample(frac = frac, random_state = 999)
            df.index = range(len(df))
        
        df.insert(0, newcolumn, value = -1.0e99)
        
        fitx = fity = fitlk = np.array([])
        
        for index, row in df.iterrows():
            model_nu = row[nucolumns].to_numpy(dtype=float)
            
            dnu_sc = obs_nu - model_nu
            dnu_lownu = dnu_sc[obs_nu<=0.7*obs_numax]
            
            lk_lownu = self.gaussian(np.median(dnu_lownu)/obs_numax, mu_lownu, sigma_lownu)
            lk_numax = self.flattop_gaussian(np.median(dnu_sc)/obs_numax, mu_numax, sigma_numax)
            
            if np.median(dnu_sc) >= 0.0:
                lk_numax = -1.0e99
            
            df.loc[index,newcolumn] = lk_lownu + lk_numax
            
            lk = np.full(len(obs_nu), np.exp(lk_lownu + lk_numax))
            
        
            fitx = np.concatenate((fitx, obs_nu))
            fity = np.concatenate((fity, dnu_sc))
            fitlk = np.concatenate((fitlk, lk))
                        
            if ((plot == True) & (np.exp(lk_lownu+lk_numax)>= 0.1)): 
                ax.scatter(obs_nu, dnu_sc,s = 5, alpha = 0.3, color = cmap(norm(np.exp(lk_lownu+lk_numax))))
            
        fitp,cov = np.polyfit(fitx, fity, 3, w = fitlk,cov = True) 
        
        mean_sys = fitp[0]*obs_nu**3.0 + fitp[1]*obs_nu**2.0 +fitp[2]*obs_nu**1.0 +fitp[3]
                
        variance = np.average( (obs_nu - df[nucolumns] - mean_sys)**2, weights = np.exp(df[newcolumn]),  axis = 0)
        
        return df, mean_sys, np.sqrt(variance)
    
sfit = smart_fit()

# %% [markdown]
# # Now we add a random noise on the fake star

# %%
# New 'observed' mode frequencies
# we add a surface term using the formula given by kjeldsen&bedding(2008)


a = -4.73
b = 4.90
obs_nu0n = obs_nu0 + a*(obs_nu0/3100)**b  + np.random.normal(loc=0.0, scale=1.0, size=len(obs_nu0))*0.5
obs_nu0n[15] = obs_nu0n[15]

fig, ax = plt.subplots()
ax.scatter(obs_nu0 % (obs_dnu), obs_nu0, c = 'k', label = 'fake star')
ax.scatter(obs_nu0n % (obs_dnu), obs_nu0n, c = 'b', label = 'realistic fake star')
ax.errorbar(obs_nu0n % (obs_dnu), obs_nu0n, xerr = 0.5, c = 'b', ls = 'None')
ax.set_xlim(25,0.5*obs_dnu)
ax.set_ylim(1400,4200)
ax.legend(loc = 'lower left')
ax.set_xlabel(r'$\nu$ mod $\Delta\nu$ ($\mu$Hz)')
ax.set_ylabel(r'$\nu$ ($\mu$Hz)')
ax.set_title("Mode frequenices of the fake star")
fig.tight_layout()
fig.savefig('fig_fake_data_2.pdf')

# %%
# and fit again

# %%
# determing the mean function (mean_sys and sigma_sys)
fig,ax = plt.subplots()
cmap = plt.cm.rainbow
norm = matplotlib.colors.Normalize(vmin=0, vmax=1)




subset, mean_f, sigma_mean  = sfit.mean_function(obs_nu = obs_nu0n, obs_numax = obs_numax,
                                                 model_df = starset,frac = 0.3, nucolumns = obsnu_0_n_text,
                                                 mu_lownu = 0.0, sigma_lownu = 0.001,
                                                 mu_numax = -0.003, sigma_numax = 0.002,
                                                 plot = True, ax = ax, cmap = cmap, norm = norm)

print(mean_f, sigma_mean)

ax.scatter(obs_nu0n, mean_f, color = 'k',s = 5, label = 'Models')
ax.plot(obs_nu0n, mean_f, color = 'k', lw = 3, label = 'Estimated mean function')
ax.fill_between(obs_nu0n, mean_f-sigma_mean, mean_f+sigma_mean, color = 'k', alpha = 0.3)
ax.plot(obs_nu0n, a*(obs_nu0/3100)**b, 'k--', lw = 3, label = 'True mean function')

ax.set_xlabel(r'$\nu_{\rm obs}$ ($\mu$Hz)')
ax.set_ylabel(r'$\nu_{\rm obs} - \nu_{\rm mod}$ ($\mu$Hz)' )
ax.legend(loc = 'lower left')
ax.set_title('Determation of the mean function')
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])
cc = fig.colorbar(sm)
cc.set_label(r'$\mathcal{L}_{\rm low-\nu} \cdot \mathcal{L}_{\rm \nu_{max}}$')
fig.tight_layout()
fig.savefig('fig_fake_mean_function_2.pdf')
# Out:
# [ -0.93017319  -0.97940168  -1.11544825  -1.34926753  -1.69032075
#   -2.14523718  -2.7284531   -3.46356715  -4.34356791  -5.3935752
#   -6.62012472  -8.02879776  -9.64409542 -11.44483419 -13.49372082
#  -15.76781006 -18.28588403 -21.05542635] [2.41862487 2.45168904 2.6028934  2.71990442 2.87406674 3.14366533
#  3.37256529 3.248425   3.59559271 3.84645195 4.11430563 4.40837048
#  4.65941715 5.16973591 5.36218491 5.68358392 5.98064845 6.30376775]

# %%
obs_nu0_e
# Out:
# array([0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5])

# %%
# Here the mean function is not zero 
mean_sys = mean_f

sigma_e = sigma_mean
length_e = 5.0*obs_dnu

sigma_u1 = 1.5*obs_nu0/obs_numax
sigma_u1_mlt = 0.0*(obs_nu0/obs_numax)
length_u1 = 20.0*obs_dnu

sigma_u2 = 0.1*(obs_numax/obs_nu0)**2.0
length_u2 = 2.0*obs_dnu


starsetn = sfit.fit_modes_cov(obs_nu = obs_nu0n, obs_nu_e = obs_nu0_e,
                             n_order = np.array(obsnu_0_n_number),obs_dnu = obs_dnu, 
                             mean_sys = mean_sys, 
                             sigma_e = sigma_e, length_e = length_e, 
                             sigma_u1 = sigma_u1, sigma_u1_mlt = sigma_u1_mlt, length_u1 = length_u1,
                             sigma_u2 = sigma_u2, length_u2 = length_u2,
                             modeldf = starset, nucolumns = obsnu_0_n_text, lkcolumn = 'lk_seismo_cn_n_normal',
                             dis = 'normal')

# %%
fontsize = 18

params = {'legend.fontsize': fontsize,
          'figure.figsize': (11, 10),
         'axes.labelsize': fontsize,
         'axes.titlesize':fontsize,
         'xtick.labelsize':fontsize,
         'ytick.labelsize':fontsize}
matplotlib.rcParams.update(params)
plt = matplotlib.pyplot

cc = ['star_mass','radius','star_age','initial_Yinit', 'initial_MLT']


figure = corner.corner(starsetn[cc], 
                       weights = np.exp(starsetn.lk_spectro + starsetn.lk_seismo_cn_n_normal),
                       bins = 20,
                       smooth=0.5,
                       truths = truths,
                       labels=[r"M (M$_{\odot}$)","R (R$_{\odot}$)", r"$\tau$ (Gyr)", r"$Y$", r"$\alpha_{\rm MLT}$"],
                       quantiles=[0.16, 0.5, 0.84],
                       range = [[0.8,1.15], [0.9,1.1] ,[0,11], [0.23,0.33], [1.6,2.6]],
                       show_titles=True, title_kwargs={"fontsize": 15})

figure.text(0.3,0.9, 'Fitting with CNM (N-distribution)',fontsize = 20)

figure.savefig('fig_coner_cn_n_normal_0miss_2.pdf')
plt.show()

# %%
# Because we intoduced another variance term while determining the mean function, not the kernel variance becomes 

# Here the mean function is not zero 
mean_sys = mean_f

sigma_e = sigma_mean
length_e = 5.0*obs_dnu

sigma_u1 = 1.5*obs_nu0/obs_numax
sigma_u1_mlt = 0.0*(obs_nu0/obs_numax)
length_u1 = 20.0*obs_dnu

sigma_u2 = 0.1*(obs_numax/obs_nu0)**2.0
length_u2 = 2.0*obs_dnu


starsetn = sfit.fit_modes_cov(obs_nu = obs_nu0n, obs_nu_e = obs_nu0_e,
                             n_order = np.array(obsnu_0_n_number),obs_dnu = obs_dnu, 
                             mean_sys = mean_sys, 
                             sigma_e = sigma_e, length_e = length_e, 
                             sigma_u1 = sigma_u1, sigma_u1_mlt = sigma_u1_mlt, length_u1 = length_u1,
                             sigma_u2 = sigma_u2, length_u2 = length_u2,
                             modeldf = starsetn, nucolumns = obsnu_0_n_text, lkcolumn = 'lk_seismo_cn_n_t',
                             dis = 't')

# %%
fontsize = 18

params = {'legend.fontsize': fontsize,
          'figure.figsize': (11, 10),
         'axes.labelsize': fontsize,
         'axes.titlesize':fontsize,
         'xtick.labelsize':fontsize,
         'ytick.labelsize':fontsize}
matplotlib.rcParams.update(params)
plt = matplotlib.pyplot

cc = ['star_mass','radius','star_age','initial_Yinit', 'initial_MLT']


figure = corner.corner(starsetn[cc], 
                       weights = np.exp(starsetn.lk_spectro + starsetn.lk_seismo_cn_n_t),
                       bins = 20,
                        smooth=0.5,
                       truths = truths,
                       labels=[r"M (M$_{\odot}$)","R (R$_{\odot}$)", r"$\tau$ (Gyr)", r"$Y$", r"$\alpha_{\rm MLT}$"],
                       quantiles=[0.16, 0.5, 0.84],
                       range = [[0.8,1.15], [0.9,1.1] ,[0,11], [0.23,0.33], [1.6,2.6]],
                       show_titles=True, title_kwargs={"fontsize": 15})

figure.text(0.3,0.9, 'Fitting with CNM (t-distribution)',fontsize = 20)

figure.savefig('fig_coner_cn_n_t_0miss_2.pdf')
